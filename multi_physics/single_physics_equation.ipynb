# %% [markdown]
# # Wave Equation

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join("..", "")))

import torch
from src.data_generator.wave_equations import WaveEquationDataset
from src.train.train import train
from src.figures.figures import plot_sample
from src.models.basic import alpha_network, u_network
from src.loss_function.loss_function import Loss


if __name__ == "__main__":

    # For PyTorch random
    torch.manual_seed(45)

    # Create Dataset
    dataset = WaveEquationDataset(n_samples=1, nx=100, nt=100,T=100, L=1)

    # Define PINNS
    alpha_net = alpha_network()
    u_net = u_network()

    # training
    u_net.train()
    alpha_net.train()

    lr = 1e-2
    optimizer = torch.optim.Adam(list(u_net.parameters()) + list(alpha_net.parameters()), lr=lr)
    loss = Loss()
    train(
        loss_function=loss,
        optimizer=optimizer,
        dataset=dataset,
        u_net=u_net,
        alpha_net=alpha_net
    )

    # plot
    u_net.eval()
    alpha_net.eval()
    sample = dataset[0]
    u_xt = u_net(xt=sample["xt"])
    plot_sample(sample, u_xt, xt_pred_mesh=sample)
# Out:
# Epoch 0: Loss = 1.6736e-01
# Epoch 20: Loss = 7.3040e-02
# Epoch 40: Loss = 6.4477e-02
# Epoch 60: Loss = 5.3462e-02
# Epoch 80: Loss = 4.0942e-02
# Epoch 100: Loss = 3.1604e-02
# Epoch 120: Loss = 2.4189e-02
# Epoch 140: Loss = 1.8383e-02
# Epoch 160: Loss = 1.3879e-02
# Epoch 180: Loss = 1.0833e-02
# Epoch 200: Loss = 8.6247e-03
# Epoch 220: Loss = 7.1934e-03
# Epoch 240: Loss = 5.8620e-03
# Epoch 260: Loss = 5.3637e-03
# Epoch 280: Loss = 4.3843e-03
# Epoch 300: Loss = 4.0017e-03
# Epoch 320: Loss = 3.4462e-03
# Epoch 340: Loss = 3.1087e-03
# Epoch 360: Loss = 3.3715e-03
# Epoch 380: Loss = 2.6932e-03
# Epoch 400: Loss = 2.4409e-03
# Epoch 420: Loss = 2.2749e-03
# Epoch 440: Loss = 2.1374e-03
# Epoch 460: Loss = 2.4386e-03
# Epoch 480: Loss = 1.9038e-03
# Epoch 500: Loss = 1.8135e-03
# Epoch 520: Loss = 1.9395e-03
# Epoch 540: Loss = 1.8079e-03
# Epoch 560: Loss = 1.5639e-03
# Epoch 580: Loss = 1.5165e-03
# Epoch 600: Loss = 1.6248e-03
# Epoch 620: Loss = 1.4256e-03
# Epoch 640: Loss = 1.3397e-03
# Epoch 660: Loss = 1.3058e-03
# Epoch 680: Loss = 1.6020e-03
# Epoch 700: Loss = 1.2627e-03
# Epoch 720: Loss = 1.1863e-03
# Epoch 740: Loss = 1.1732e-03
# Epoch 760: Loss = 1.1432e-03
# Epoch 780: Loss = 1.1178e-03
# Epoch 800: Loss = 1.0507e-03
# Epoch 820: Loss = 1.0224e-03
# Epoch 840: Loss = 1.8181e-03
# Epoch 860: Loss = 9.7152e-04
# Epoch 880: Loss = 9.6012e-04
# Epoch 900: Loss = 9.3419e-04
# Epoch 920: Loss = 9.0432e-04
# Epoch 940: Loss = 9.2998e-04
# Epoch 960: Loss = 8.7065e-04
# Epoch 980: Loss = 1.0040e-03
# Epoch 1000: Loss = 8.8278e-04
# Epoch 1020: Loss = 8.2343e-04
# Epoch 1040: Loss = 1.1474e-03
# Epoch 1060: Loss = 7.9082e-04
# Epoch 1080: Loss = 7.7119e-04
# Epoch 1100: Loss = 1.5794e-03
# Epoch 1120: Loss = 8.1850e-04
# Epoch 1140: Loss = 7.2948e-04
# Epoch 1160: Loss = 7.1718e-04
# Epoch 1180: Loss = 7.0658e-04
# Epoch 1200: Loss = 8.6532e-04
# Epoch 1220: Loss = 6.8698e-04
# Epoch 1240: Loss = 6.8294e-04
# Epoch 1260: Loss = 6.6226e-04
# Epoch 1280: Loss = 6.5119e-04
# Epoch 1300: Loss = 8.3884e-04
# Epoch 1320: Loss = 7.3161e-04
# Epoch 1340: Loss = 6.2392e-04
# Epoch 1360: Loss = 6.1482e-04
# Epoch 1380: Loss = 6.0716e-04
# Epoch 1400: Loss = 6.2807e-04
# Epoch 1420: Loss = 8.5724e-04
# Epoch 1440: Loss = 5.9257e-04
# Epoch 1460: Loss = 5.8022e-04
# Epoch 1480: Loss = 5.6986e-04
# Epoch 1500: Loss = 5.6324e-04
# Epoch 1520: Loss = 1.7690e-03
# Epoch 1540: Loss = 6.2471e-04
# Epoch 1560: Loss = 5.4781e-04
# Epoch 1580: Loss = 5.3970e-04
# Epoch 1600: Loss = 5.3118e-04
# Epoch 1620: Loss = 5.2506e-04
# Epoch 1640: Loss = 5.2132e-04
# Epoch 1660: Loss = 5.4484e-04
# Epoch 1680: Loss = 6.0512e-04
# Epoch 1700: Loss = 5.0765e-04
# Epoch 1720: Loss = 4.9999e-04
# Epoch 1740: Loss = 4.9419e-04
# Epoch 1760: Loss = 4.8900e-04
# Epoch 1780: Loss = 4.8417e-04
# Epoch 1800: Loss = 4.7959e-04
# Epoch 1820: Loss = 7.6435e-04
# Epoch 1840: Loss = 6.3559e-04
# Epoch 1860: Loss = 4.7044e-04
# Epoch 1880: Loss = 4.6377e-04
# Epoch 1900: Loss = 4.5898e-04
# Epoch 1920: Loss = 4.5449e-04
# Epoch 1940: Loss = 4.5047e-04
# Epoch 1960: Loss = 4.4657e-04
# Epoch 1980: Loss = 4.4338e-04
# Epoch 2000: Loss = 1.7190e-03
# Epoch 2020: Loss = 4.7123e-04
# Epoch 2040: Loss = 4.4428e-04
# Epoch 2060: Loss = 4.3150e-04
# Epoch 2080: Loss = 4.2575e-04
# Epoch 2100: Loss = 4.2229e-04
# Epoch 2120: Loss = 4.1893e-04
# Epoch 2140: Loss = 4.1573e-04
# Epoch 2160: Loss = 4.1265e-04
# Epoch 2180: Loss = 4.8217e-04
# Epoch 2200: Loss = 4.4699e-04
# Epoch 2220: Loss = 4.4693e-04
# Epoch 2240: Loss = 4.0569e-04
# Epoch 2260: Loss = 3.9914e-04
# Epoch 2280: Loss = 3.9544e-04
# Epoch 2300: Loss = 3.9264e-04
# Epoch 2320: Loss = 3.8995e-04
# Epoch 2340: Loss = 3.8735e-04
# Epoch 2360: Loss = 3.8557e-04
# Epoch 2380: Loss = 1.6363e-03
# Epoch 2400: Loss = 4.9315e-04
# Epoch 2420: Loss = 3.8506e-04
# Epoch 2440: Loss = 3.7684e-04
# Epoch 2460: Loss = 3.7287e-04
# Epoch 2480: Loss = 3.7040e-04
# Epoch 2500: Loss = 3.6809e-04
# Epoch 2520: Loss = 3.6589e-04
# Epoch 2540: Loss = 3.6375e-04
# Epoch 2560: Loss = 3.6412e-04
# Epoch 2580: Loss = 4.1480e-04
# Epoch 2600: Loss = 4.1046e-04
# Epoch 2620: Loss = 3.6805e-04
# Epoch 2640: Loss = 3.5511e-04
# Epoch 2660: Loss = 3.5137e-04
# Epoch 2680: Loss = 3.4935e-04
# Epoch 2700: Loss = 3.4741e-04
# Epoch 2720: Loss = 3.4557e-04
# Epoch 2740: Loss = 3.4377e-04
# Epoch 2760: Loss = 3.4206e-04
# Epoch 2780: Loss = 5.4251e-04
# Epoch 2800: Loss = 5.1532e-04
# Epoch 2820: Loss = 3.6115e-04
# Epoch 2840: Loss = 3.3562e-04
# Epoch 2860: Loss = 3.3356e-04
# Epoch 2880: Loss = 3.3139e-04
# Epoch 2900: Loss = 3.2975e-04
# Epoch 2920: Loss = 3.2815e-04
# Epoch 2940: Loss = 3.2657e-04
# Epoch 2960: Loss = 3.2509e-04
# Epoch 2980: Loss = 5.4492e-04

# %% [markdown]
# # Diffusion Equation

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join("..", "")))

import torch
from src.data_generator.diffusion_equations import DiffusionEquationDataset
from src.train.train import train
from src.figures.figures import plot_sample
from src.models.basic import alpha_network, u_network
from src.loss_function.loss_function import Loss


if __name__ == "__main__":

    # Create Dataset
    dataset = DiffusionEquationDataset(n_samples=1, nx=100, nt=100,T=100, L=1)

    # Define PINNS
    alpha_net = alpha_network()
    u_net = u_network()

    # training
    u_net.train()
    alpha_net.train()

    lr = 1e-2
    optimizer = torch.optim.Adam(list(u_net.parameters()) + list(alpha_net.parameters()), lr=lr)
    loss = Loss()
    train(
        loss_function=loss,
        optimizer=optimizer,
        dataset=dataset,
        u_net=u_net,
        alpha_net=alpha_net
    )

    # plot
    u_net.eval()
    alpha_net.eval()
    sample = dataset[0]
    u_xt = u_net(xt=sample["xt"])
    plot_sample(sample, u_xt, xt_pred_mesh=sample)
# Out:
# Epoch 0: Loss = 1.8847e-01
# Epoch 20: Loss = 8.3082e-02
# Epoch 40: Loss = 7.0985e-02
# Epoch 60: Loss = 6.6712e-02
# Epoch 80: Loss = 6.5557e-02
# Epoch 100: Loss = 6.5184e-02
# Epoch 120: Loss = 6.5009e-02
# Epoch 140: Loss = 6.4903e-02
# Epoch 160: Loss = 6.4826e-02
# Epoch 180: Loss = 6.4766e-02
# Epoch 200: Loss = 6.4737e-02
# Epoch 220: Loss = 6.4692e-02
# Epoch 240: Loss = 6.4658e-02
# Epoch 260: Loss = 6.4637e-02
# Epoch 280: Loss = 6.4369e-02
# Epoch 300: Loss = 6.2634e-02
# Epoch 320: Loss = 5.2780e-02
# Epoch 340: Loss = 3.7594e-02
# Epoch 360: Loss = 2.5703e-02
# Epoch 380: Loss = 1.8652e-02
# Epoch 400: Loss = 1.4049e-02
# Epoch 420: Loss = 1.1455e-02
# Epoch 440: Loss = 1.0223e-02
# Epoch 460: Loss = 8.7867e-03
# Epoch 480: Loss = 8.1169e-03
# Epoch 500: Loss = 7.5674e-03
# Epoch 520: Loss = 7.1485e-03
# Epoch 540: Loss = 6.6710e-03
# Epoch 560: Loss = 5.8476e-03
# Epoch 580: Loss = 5.6930e-03
# Epoch 600: Loss = 4.2634e-03
# Epoch 620: Loss = 3.6440e-03
# Epoch 640: Loss = 3.2544e-03
# Epoch 660: Loss = 3.1821e-03
# Epoch 680: Loss = 3.1592e-03
# Epoch 700: Loss = 2.5963e-03
# Epoch 720: Loss = 2.4051e-03
# Epoch 740: Loss = 2.2542e-03
# Epoch 760: Loss = 2.2718e-03
# Epoch 780: Loss = 2.0253e-03
# Epoch 800: Loss = 1.9081e-03
# Epoch 820: Loss = 2.2168e-03
# Epoch 840: Loss = 1.7341e-03
# Epoch 860: Loss = 1.6522e-03
# Epoch 880: Loss = 1.9683e-03
# Epoch 900: Loss = 1.5371e-03
# Epoch 920: Loss = 1.4840e-03
# Epoch 940: Loss = 1.4245e-03
# Epoch 960: Loss = 2.2663e-03
# Epoch 980: Loss = 1.3966e-03
# Epoch 1000: Loss = 1.3020e-03
# Epoch 1020: Loss = 1.4384e-03
# Epoch 1040: Loss = 1.2804e-03
# Epoch 1060: Loss = 1.3610e-03
# Epoch 1080: Loss = 1.2538e-03
# Epoch 1100: Loss = 1.3593e-03
# Epoch 1120: Loss = 1.1526e-03
# Epoch 1140: Loss = 1.1025e-03
# Epoch 1160: Loss = 1.5124e-03
# Epoch 1180: Loss = 1.0653e-03
# Epoch 1200: Loss = 1.0297e-03
# Epoch 1220: Loss = 1.0071e-03
# Epoch 1240: Loss = 1.5048e-03
# Epoch 1260: Loss = 9.8220e-04
# Epoch 1280: Loss = 9.6175e-04
# Epoch 1300: Loss = 9.3535e-04
# Epoch 1320: Loss = 1.1438e-03
# Epoch 1340: Loss = 9.0955e-04
# Epoch 1360: Loss = 8.9061e-04
# Epoch 1380: Loss = 8.7161e-04
# Epoch 1400: Loss = 1.5172e-03
# Epoch 1420: Loss = 8.8898e-04
# Epoch 1440: Loss = 8.5229e-04
# Epoch 1460: Loss = 8.2128e-04
# Epoch 1480: Loss = 2.4317e-03
# Epoch 1500: Loss = 8.7964e-04
# Epoch 1520: Loss = 8.3338e-04
# Epoch 1540: Loss = 7.9257e-04
# Epoch 1560: Loss = 8.4624e-04
# Epoch 1580: Loss = 9.6815e-04
# Epoch 1600: Loss = 7.6386e-04
# Epoch 1620: Loss = 7.3965e-04
# Epoch 1640: Loss = 7.9082e-04
# Epoch 1660: Loss = 9.2070e-04
# Epoch 1680: Loss = 7.4867e-04
# Epoch 1700: Loss = 6.6352e-04
# Epoch 1720: Loss = 6.4946e-04
# Epoch 1740: Loss = 6.3925e-04
# Epoch 1760: Loss = 6.3331e-04
# Epoch 1780: Loss = 6.2682e-04
# Epoch 1800: Loss = 6.1418e-04
# Epoch 1820: Loss = 6.0763e-04
# Epoch 1840: Loss = 6.7268e-04
# Epoch 1860: Loss = 5.9178e-04
# Epoch 1880: Loss = 6.6335e-04
# Epoch 1900: Loss = 6.6577e-04
# Epoch 1920: Loss = 6.1464e-04
# Epoch 1940: Loss = 6.0627e-04
# Epoch 1960: Loss = 5.7267e-04
# Epoch 1980: Loss = 5.5554e-04
# Epoch 2000: Loss = 5.6720e-04
# Epoch 2020: Loss = 5.6162e-04
# Epoch 2040: Loss = 5.5435e-04
# Epoch 2060: Loss = 5.6075e-04
# Epoch 2080: Loss = 5.4787e-04
# Epoch 2100: Loss = 5.5305e-04
# Epoch 2120: Loss = 6.1404e-04
# Epoch 2140: Loss = 7.3167e-04
# Epoch 2160: Loss = 5.3347e-04
# Epoch 2180: Loss = 5.9261e-04
# Epoch 2200: Loss = 6.7950e-04
# Epoch 2220: Loss = 6.9103e-04
# Epoch 2240: Loss = 6.9980e-04
# Epoch 2260: Loss = 5.1940e-04
# Epoch 2280: Loss = 4.9666e-04
# Epoch 2300: Loss = 5.6584e-04
# Epoch 2320: Loss = 5.9931e-04
# Epoch 2340: Loss = 6.6758e-04
# Epoch 2360: Loss = 5.2647e-04
# Epoch 2380: Loss = 5.2394e-04
# Epoch 2400: Loss = 8.2559e-04
# Epoch 2420: Loss = 6.0793e-04
# Epoch 2440: Loss = 7.1671e-04
# Epoch 2460: Loss = 4.8789e-04
# Epoch 2480: Loss = 4.9843e-04
# Epoch 2500: Loss = 5.2433e-04
# Epoch 2520: Loss = 6.1947e-04
# Epoch 2540: Loss = 6.7723e-04
# Epoch 2560: Loss = 5.4280e-04
# Epoch 2580: Loss = 4.5770e-04
# Epoch 2600: Loss = 4.8138e-04
# Epoch 2620: Loss = 4.6508e-04
# Epoch 2640: Loss = 4.6432e-04
# Epoch 2660: Loss = 5.5523e-04
# Epoch 2680: Loss = 6.4923e-04
# Epoch 2700: Loss = 6.8170e-04
# Epoch 2720: Loss = 5.6733e-04
# Epoch 2740: Loss = 5.2108e-04
# Epoch 2760: Loss = 5.1052e-04
# Epoch 2780: Loss = 7.9106e-04
# Epoch 2800: Loss = 4.4666e-04
# Epoch 2820: Loss = 4.5282e-04
# Epoch 2840: Loss = 6.0808e-04
# Epoch 2860: Loss = 5.6056e-04
# Epoch 2880: Loss = 7.9855e-04
# Epoch 2900: Loss = 4.2892e-04
# Epoch 2920: Loss = 5.1359e-04
# Epoch 2940: Loss = 7.1247e-04
# Epoch 2960: Loss = 5.2672e-04
# Epoch 2980: Loss = 5.8341e-04
