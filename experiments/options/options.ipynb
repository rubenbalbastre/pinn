# %% [markdown]
# # Options: Black-Scholes Equation
#
# Options price is generally modeled using Black-Scholes differential equation. Here, we try to solve it using PINNs.

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join("..", "")))

import torch
from options_equations import OptionsDataset
from train_options_pinn import train_options_pinn
from model import OptionPriceNetwork
from loss import Loss


# For PyTorch random
torch.manual_seed(45)

# Create Dataset
Smax = 120.0
T = 10.0
K = 60.0
r = 0.03
sigma = 0.2
dataset = OptionsDataset(n_samples=1, nS=20, nt=20, Smax=Smax, T=T)

# Define PINNs
option_net = OptionPriceNetwork(hidden_dim=32)

# training
option_net.train()

lr = 1e-2
optimizer = torch.optim.Adam(list(option_net.parameters()), lr=lr)
loss = Loss(T=T, K=K, r=r, sigma=sigma)
losses = train_options_pinn(
    loss_function=loss,
    optimizer=optimizer,
    dataset=dataset,
    options_price_net=option_net,
    epochs=3000
)
# Out:
# Epoch 0: Loss = 1.4957e+03
# Epoch 20: Loss = 1.4624e+03
# Epoch 40: Loss = 1.4622e+03
# Epoch 60: Loss = 1.4622e+03
# Epoch 80: Loss = 1.4622e+03
# Epoch 100: Loss = 1.4622e+03
# Epoch 120: Loss = 1.4622e+03
# Epoch 140: Loss = 1.4622e+03
# Epoch 160: Loss = 1.4622e+03
# Epoch 180: Loss = 1.4622e+03
# Epoch 200: Loss = 1.4622e+03
# Epoch 220: Loss = 1.4622e+03
# Epoch 240: Loss = 1.4622e+03
# Epoch 260: Loss = 1.4622e+03
# Epoch 280: Loss = 1.4622e+03
# Epoch 300: Loss = 1.4622e+03
# Epoch 320: Loss = 1.4622e+03
# Epoch 340: Loss = 1.4622e+03
# Epoch 360: Loss = 1.4622e+03
# Epoch 380: Loss = 1.4622e+03
# Epoch 400: Loss = 1.4622e+03
# Epoch 420: Loss = 1.4622e+03
# Epoch 440: Loss = 1.4622e+03
# Epoch 460: Loss = 1.4622e+03
# Epoch 480: Loss = 1.4622e+03
# Epoch 500: Loss = 1.4622e+03
# Epoch 520: Loss = 1.4622e+03
# Epoch 540: Loss = 1.4622e+03
# Epoch 560: Loss = 1.4622e+03
# Epoch 580: Loss = 1.4622e+03
# Epoch 600: Loss = 1.4622e+03
# Epoch 620: Loss = 1.4622e+03
# Epoch 640: Loss = 1.4622e+03
# Epoch 660: Loss = 1.4622e+03
# Epoch 680: Loss = 1.4622e+03
# Epoch 700: Loss = 1.4622e+03
# Epoch 720: Loss = 1.4622e+03
# Epoch 740: Loss = 1.4622e+03
# Epoch 760: Loss = 1.4622e+03
# Epoch 780: Loss = 1.4622e+03
# Epoch 800: Loss = 1.4622e+03
# Epoch 820: Loss = 1.4622e+03
# Epoch 840: Loss = 1.4622e+03
# Epoch 860: Loss = 1.4622e+03
# Epoch 880: Loss = 1.4622e+03
# Epoch 900: Loss = 1.4622e+03
# Epoch 920: Loss = 1.4622e+03
# Epoch 940: Loss = 1.4622e+03
# Epoch 960: Loss = 1.4622e+03
# Epoch 980: Loss = 1.4622e+03
# Epoch 1000: Loss = 1.4622e+03
# Epoch 1020: Loss = 1.4622e+03
# Epoch 1040: Loss = 1.4622e+03
# Epoch 1060: Loss = 1.4622e+03
# Epoch 1080: Loss = 1.4622e+03
# Epoch 1100: Loss = 1.4622e+03
# Epoch 1120: Loss = 1.4622e+03
# Epoch 1140: Loss = 1.4622e+03
# Epoch 1160: Loss = 1.4622e+03
# Epoch 1180: Loss = 1.4622e+03
# Epoch 1200: Loss = 1.4622e+03
# Epoch 1220: Loss = 1.4622e+03
# Epoch 1240: Loss = 1.4622e+03
# Epoch 1260: Loss = 1.4622e+03
# Epoch 1280: Loss = 1.4622e+03
# Epoch 1300: Loss = 1.4622e+03
# Epoch 1320: Loss = 1.4622e+03
# Epoch 1340: Loss = 1.4622e+03
# Epoch 1360: Loss = 1.4622e+03
# Epoch 1380: Loss = 1.4622e+03
# Epoch 1400: Loss = 1.4622e+03
# Epoch 1420: Loss = 1.4622e+03
# Epoch 1440: Loss = 1.4622e+03
# Epoch 1460: Loss = 1.4622e+03
# Epoch 1480: Loss = 1.4622e+03
# Epoch 1500: Loss = 1.4622e+03
# Epoch 1520: Loss = 1.4622e+03
# Epoch 1540: Loss = 1.4622e+03
# Epoch 1560: Loss = 1.4622e+03
# Epoch 1580: Loss = 1.4622e+03
# Epoch 1600: Loss = 1.4622e+03
# Epoch 1620: Loss = 1.4622e+03
# Epoch 1640: Loss = 1.4622e+03
# Epoch 1660: Loss = 1.4622e+03
# Epoch 1680: Loss = 1.4622e+03
# Epoch 1700: Loss = 1.4622e+03
# Epoch 1720: Loss = 1.4622e+03
# Epoch 1740: Loss = 1.4622e+03
# Epoch 1760: Loss = 1.4622e+03
# Epoch 1780: Loss = 1.4622e+03
# Epoch 1800: Loss = 1.4622e+03
# Epoch 1820: Loss = 1.4622e+03
# Epoch 1840: Loss = 1.4622e+03
# Epoch 1860: Loss = 1.4622e+03
# Epoch 1880: Loss = 1.4622e+03
# Epoch 1900: Loss = 1.4622e+03
# Epoch 1920: Loss = 1.4622e+03
# Epoch 1940: Loss = 1.4622e+03
# Epoch 1960: Loss = 1.4622e+03
# Epoch 1980: Loss = 1.4622e+03
# Epoch 2000: Loss = 1.4622e+03
# Epoch 2020: Loss = 1.4622e+03
# Epoch 2040: Loss = 1.4622e+03
# Epoch 2060: Loss = 1.4622e+03
# Epoch 2080: Loss = 1.4622e+03
# Epoch 2100: Loss = 1.4622e+03
# Epoch 2120: Loss = 1.4622e+03
# Epoch 2140: Loss = 1.4622e+03
# Epoch 2160: Loss = 1.4622e+03
# Epoch 2180: Loss = 1.4622e+03
# Epoch 2200: Loss = 1.4622e+03
# Epoch 2220: Loss = 1.4622e+03
# Epoch 2240: Loss = 1.4622e+03
# Epoch 2260: Loss = 1.4622e+03
# Epoch 2280: Loss = 1.4622e+03
# Epoch 2300: Loss = 1.4622e+03
# Epoch 2320: Loss = 1.4622e+03
# Epoch 2340: Loss = 1.4622e+03
# Epoch 2360: Loss = 1.4622e+03
# Epoch 2380: Loss = 1.4622e+03
# Epoch 2400: Loss = 1.4622e+03
# Epoch 2420: Loss = 1.4622e+03
# Epoch 2440: Loss = 1.4622e+03
# Epoch 2460: Loss = 1.4622e+03
# Epoch 2480: Loss = 1.4622e+03
# Epoch 2500: Loss = 1.4622e+03
# Epoch 2520: Loss = 1.4622e+03
# Epoch 2540: Loss = 1.4622e+03
# Epoch 2560: Loss = 1.4622e+03
# Epoch 2580: Loss = 1.4622e+03
# Epoch 2600: Loss = 1.4622e+03
# Epoch 2620: Loss = 1.4622e+03
# Epoch 2640: Loss = 1.4622e+03
# Epoch 2660: Loss = 1.4622e+03
# Epoch 2680: Loss = 1.4622e+03
# Epoch 2700: Loss = 1.4622e+03
# Epoch 2720: Loss = 1.4622e+03
# Epoch 2740: Loss = 1.4622e+03
# Epoch 2760: Loss = 1.4622e+03
# Epoch 2780: Loss = 1.4622e+03
# Epoch 2800: Loss = 1.4622e+03
# Epoch 2820: Loss = 1.4622e+03
# Epoch 2840: Loss = 1.4622e+03
# Epoch 2860: Loss = 1.4622e+03
# Epoch 2880: Loss = 1.4622e+03
# Epoch 2900: Loss = 1.4622e+03
# Epoch 2920: Loss = 1.4622e+03
# Epoch 2940: Loss = 1.4622e+03
# Epoch 2960: Loss = 1.4622e+03
# Epoch 2980: Loss = 1.4622e+03
